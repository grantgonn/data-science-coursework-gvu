# %% [markdown]
# # Exercise 1 (3 points)
#
# Which of the following is a key distinction between non-stochastic and stochastic simulations?
#
# - (a) Use of computer code
# - (b) Type of decision-making models
# - (c) Use of random variations
# - (d) Implementation cost
# - (e) All of the above

# %% [markdown]
# C

# %% [markdown]
# # Exercise 2 (4 points)
#
# Differentiate between natural and pseudo-random numbers with examples.

# %% [markdown]
# Natural random numbers are generated by a phisical phenomena such as he lottery numbers being drawn where as pseudo-random is generated by algorithms.

# %% [markdown]
# # Exercise 3 (3 points)
#
# In a simulation model, what is the purpose of the `seed` in a random number generator?
#
# - (a) To store the model results
# - (b) To initialize the simulation model
# - (c) To control random number reproducibility
# - (d) To scale results
# - (e) None of the above

# %% [markdown]
# C

# %% [markdown]
# # Exercise 4 (4 points)
#
# List and explain at least three types of shocks that might influence a business system.

# %% [markdown]
# - Economic shocks such as market crashes, and inflation
# - Technological shocks such as the introduction of new technologies like we have seen with ai or breakdowns like in a cyber attack
# - Natural shocks such as natural disasters like earthquakes, wildfires, floods, or pandemics like COVID

# %% [markdown]
# # Exercise 5 (3 points)
#
# What is the key advantage of using simulations for decision-making?
#
# - (a) Eliminates the need for data
# - (b) Allows for real-time decisions
# - (c) Enables testing of various scenarios without impacting the real system
# - (d) Reduces need for programming skills
# - (e) None of the above

# %% [markdown]
# C

# %% [markdown]
# # Exercise 6 (3 points)
#
# Generate a list of 10 uniformly distributed random numbers between 5 and 15 using `numpy`.

# %%
import numpy as np

random_numbers = np.random.uniform(5, 15, 10)
print(random_numbers)
# Out:
# [13.10976066  9.78924088 12.46732267  8.36005172  9.94771271  6.20587768
#   9.67488632  6.30036706 10.5178757   6.60654602]

# %% [markdown]
# # Exercise 7 (5 points)
#
# Simulate the effect of a random shock on quarterly revenue using NumPy. Let base revenue = 100, and the shock follows $N(0, 10)$. Simulate for 8 quarters.

# %%
base_rev = 100
quarters = 8
shocks = np.random.normal(0, 10, quarters)
revenue = base_rev + shocks
print("Quarterly revenues with shocks:", revenue)
# Out:
# Quarterly revenues with shocks: [106.00676826 109.62649866 108.55029207 103.46193427  92.64521214
#  114.69850269  91.45119407 105.38971496]

# %% [markdown]
# # Exercise 8 (7 points)
#
# Write a Python function that runs a simple Monte Carlo simulation to estimate the value of $\pi$ using 10,000 iterations.

# %%
def estimate_pi(itterations = 10000):
    count = 0
    for _ in range(itterations):
        x, y = np.random.uniform(0, 1, 2)
        if x**2 + y**2 <= 1:
            count += 1
    pi_estimate = (count / itterations) * 4
    return pi_estimate

print("Estimated value of Pi:", estimate_pi())
# Out:
# Estimated value of Pi: 3.1472
