# %% [markdown]
# # Exercise 1 (4 points)
#
# Explain the evolution of analytics and name its three main forms.

# %% [markdown]
# Analyics evolved from basic statistics into a broader data science, which is split into descriptive, predictive, and prescriptive analytics
#
# - descriptive: what has happened
# - predictive: estimating what will happen
# - prescriptive: recommending what should be done

# %% [markdown]
# # Exercise 2 (4 points)
#
# How does Prescriptive Analytics differ from Predictive Analytics?

# %% [markdown]
# Predictive analytics povides a menu of options based on forcasts or predictions while prescriptive analytics helps to narrow that menu or options to recommend the best course of action considering bussiness constraints and goals

# %% [markdown]
# # Exercise 3 (4 points)
#
# Why is communication between data scientists and business managers often problematic?

# %% [markdown]
# It can be problematic because data scientists and business managers often dont speak the same language. This creates a communication gap that can cause problems in implimentaion.

# %% [markdown]
# # Exercise 4 (10 points)
#
# Consider the `Bank_Churners.csv` data file. This data file contains information related to credit card customers of some bank. This is a brief description of the data:
#
# - `CLIENTNUM` : Client number. Unique identifier for the customer holding the account
# - `Attrition_Flag` : Internal event (customer activity) variable - if the account is closed then 1 else 0
# - `Customer_Age` : Demographic variable - Customer's Age in Years
# - `Gender` : M=Male, F=Female
# - `Dependent_count` : Number of dependents
# - `Education_Level` : Educational Qualification of the account holder (example: high school, college graduate, etc.)
# - `Marital_Status` : Married, Single, Divorced, Unknown
# - `Income_Category` : Annual Income Category of the account holder < $40K, $40K - 60K, $60K - $80K, $80K-$120K
# - `Card_Category` : Product Variable - Type of Card (Blue, Silver, Gold, Platinum)
# - `Months_on_book` : Period of relationship with bank
# - `Total_Relationship_count` : Total no. of products held by the customer
# - `Months_Inactive_12_mon` : No. of months inactive in the last 12 months
# - `Contacts_Count_12_mon` : No. of Contacts in the last 12 months
# - `Credit_Limit` : Credit Limit on the Credit Card
# - `Total_Revolving_Bal` : Total Revolving Balance on the Credit Card
# - `Avg_Open_To_Buy` : Open to Buy Credit Line (Average of last 12 months)
# - `Total_Amt_Chng_Q4_Q1` : Change in Transaction Amount (Q4 over Q1)
# - `Total_Trans_Amt` : Total Transaction Amount (Last 12 months)
# - `Total_Trans_Ct` : Total Transaction Count (Last 12 months)
# - `Total_Ct_Chng_Q4_Q1` : Change in Transaction Count (Q4 over Q1)
# - `Avg_Utilization_Ratio` : Average Card Utilization Ratio
#
# Explore the data.

# %%
import pandas as pd; pd.set_option('display.max_columns', None)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv('Bank_Churners.csv')
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# 0              39                         5                       1
# ...

# %%
df.isna().sum(axis=0)
# Out:
# CLIENTNUM                   0
# Attrition_Flag              0
# Customer_Age                0
# Gender                      0
# Dependent_count             0
# Education_Level             0
# Marital_Status              0
# Income_Category             0
# Card_Category               0
# Months_on_book              0
# Total_Relationship_Count    0
# Months_Inactive_12_mon      0
# Contacts_Count_12_mon       0
# Credit_Limit                0
# Total_Revolving_Bal         0
# Avg_Open_To_Buy             0
# Total_Amt_Chng_Q4_Q1        0
# Total_Trans_Amt             0
# Total_Trans_Ct              0
# Total_Ct_Chng_Q4_Q1         0
# Avg_Utilization_Ratio       0
# dtype: int64

# %%
df['CLIENTNUM'].nunique() == df.shape[0]
# Out:
# True

# %%
df['Attrition_Flag'].value_counts(normalize=True)
# Out:
# Attrition_Flag
# Existing Customer    0.83934
# Attrited Customer    0.16066
# Name: proportion, dtype: float64

# %%
# distribution of credit limit by attrition flag
sns.histplot(data=df, x='Credit_Limit', hue='Attrition_Flag', multiple='stack', bins=30)
plt.title('Distribution of Credit Limit by Attrition Flag')
plt.xlabel('Credit Limit')
plt.ylabel('Count')
plt.show()

# %%
# distribution of Total_Revolving_Bal by attrition flag
sns.histplot(data=df, x='Total_Revolving_Bal', hue='Attrition_Flag', multiple='stack', bins=30)
plt.title('Distribution of Total_Revolving_Bal by Attrition Flag')
plt.xlabel('Total_Revolving_Bal')
plt.ylabel('Count')
plt.show()

# %%
# distribution of Avg_Open_To_Buy by attrition flag
sns.histplot(data=df, x='Avg_Open_To_Buy', hue='Attrition_Flag', multiple='stack', bins=30)
plt.title('Distribution of Avg_Open_To_Buy by Attrition Flag')
plt.xlabel('Avg_Open_To_Buy')
plt.ylabel('Count')
plt.show()

# %%
# distribution of Avg_Open_To_Buy by attrition flag
sns.histplot(data=df, x='Total_Trans_Amt', hue='Attrition_Flag', multiple='stack', bins=30)
plt.title('Distribution of Total_Trans_Amt by Attrition Flag')
plt.xlabel('Total_Trans_Amt')
plt.ylabel('Count')
plt.show()

# %%
# distribution of Avg_Open_To_Buy by attrition flag
sns.histplot(data=df, x='Avg_Utilization_Ratio', hue='Attrition_Flag', multiple='stack', bins=30)
plt.title('Distribution of Avg_Utilization_Ratio by Attrition Flag')
plt.xlabel('Avg_Utilization_Ratio')
plt.ylabel('Count')
plt.show()

# %%
# distribution of Avg_Open_To_Buy by attrition flag
sns.histplot(data=df, x='Customer_Age', hue='Attrition_Flag', multiple='stack', bins=30)
plt.title('Distribution of Customer_Age by Attrition Flag')
plt.xlabel('Customer_Age')
plt.ylabel('Count')
plt.show()
